# %%
Student_name = ('Roland Bennette Valencia')
Student_pace = ('Part time')
Scheduled_project = ('March 31 2024')
Instructor_name = ('Rajive Islam')

# %%
# Importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
# Uploading data frame 1
df1 = pd.read_csv('imdb.title.ratings.csv.gz')
df1
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
# Uploading data frame 2
df2 = pd.read_csv('imdb.title.basics.csv.gz')
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
# Uploading data frame 3
df3 = pd.read_csv('bom.movie_gross.csv.gz')
df3
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
# Uploading data frame
df4 = pd.read_csv('tn.movie_budgets.csv.gz')
df4
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
# Renaming column movie to title for merging.
df4.rename(columns={'movie': 'title'}, inplace=True)
df4
# Out:
#       id  release_date                                        title  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
# Merging data frames 1 and 2 using 'inner join'.

merged_df = pd.merge(df2,df1,on='tconst',how='inner')
merged_df
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
# Renaming column name for merging
merged_df.rename(columns={'primary_title': 'title'}, inplace=True)
merged_df
# Out:
#           tconst                            title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
# Merging data frames 4 and 3 using 'inner join'.

merged_df1 = pd.merge(df4,df3,on='title',how='inner')
merged_df1
# Out:
#       id  release_date                                        title  \
# 0      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1      4   May 1, 2015                      Avengers: Age of Ultron
# 2      7  Apr 27, 2018                       Avengers: Infinity War
# 3      9  Nov 17, 2017                               Justice League
# 4     10   Nov 6, 2015                                      Spectre
# ...   ..           ...                                          ...
# 1242  68  Apr 27, 2012                            Sound of My Voice
# 1243  73  Jun 15, 2012                         Your Sister's Sister
# 1244  80  Jul 10, 2015                                  The Gallows
# 1245  86   Jul 7, 2017                                A Ghost Story
# 1246  18  Nov 12, 2010                               Tiny Furniture
#
#      production_budget domestic_gross_x worldwide_gross   studio  \
# 0         $410,600,000     $241,063,875  $1,045,663,875       BV
# ...

# %%
# Merging data frames
merged_df2 = pd.merge(merged_df1,merged_df,on='title',how='inner')
merged_df2
# Out:
#       id  release_date                                        title  \
# 0      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1      4   May 1, 2015                      Avengers: Age of Ultron
# 2      7  Apr 27, 2018                       Avengers: Infinity War
# 3      9  Nov 17, 2017                               Justice League
# 4     10   Nov 6, 2015                                      Spectre
# ...   ..           ...                                          ...
# 1408  68  Apr 27, 2012                            Sound of My Voice
# 1409  73  Jun 15, 2012                         Your Sister's Sister
# 1410  80  Jul 10, 2015                                  The Gallows
# 1411  86   Jul 7, 2017                                A Ghost Story
# 1412  18  Nov 12, 2010                               Tiny Furniture
#
#      production_budget domestic_gross_x worldwide_gross   studio  \
# 0         $410,600,000     $241,063,875  $1,045,663,875       BV
# ...

# %%
# To look for null values
merged_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1413 entries, 0 to 1412
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 1413 non-null   int64
#  1   release_date       1413 non-null   object
#  2   title              1413 non-null   object
#  3   production_budget  1413 non-null   object
#  4   domestic_gross_x   1413 non-null   object
#  5   worldwide_gross    1413 non-null   object
#  6   studio             1413 non-null   object
#  7   domestic_gross_y   1412 non-null   float64
#  8   foreign_gross      1215 non-null   object
#  9   year               1413 non-null   int64
#  10  tconst             1413 non-null   object
#  11  original_title     1413 non-null   object
#  12  start_year         1413 non-null   int64
#  13  runtime_minutes    1383 non-null   float64
#  14  genres             1406 non-null   object
#  15  averagerating      1413 non-null   float64
# ...

# %%
# To show basic statistics
merged_df2.describe()
# Out:
#                 id  domestic_gross_y         year   start_year  \
# count  1413.000000      1.412000e+03  1413.000000  1413.000000
# mean     51.659590      6.034071e+07  2013.726115  2013.644020
# std      28.606088      8.443935e+07     2.530131     2.531381
# min       1.000000      8.000000e+02  2010.000000  2010.000000
# 25%      27.000000      7.175000e+06  2011.000000  2011.000000
# 50%      52.000000      3.365000e+07  2014.000000  2014.000000
# 75%      76.000000      7.422500e+07  2016.000000  2016.000000
# max     100.000000      7.001000e+08  2018.000000  2019.000000
#
#        runtime_minutes  averagerating      numvotes
# count      1383.000000    1413.000000  1.413000e+03
# mean        107.242950       6.434961  1.133554e+05
# std          19.737869       1.029822  1.640935e+05
# min           3.000000       1.600000  5.000000e+00
# 25%          94.000000       5.900000  1.292600e+04
# 50%         105.000000       6.500000  5.895500e+04
# ...

# %%
# To look for duplicate values
merged_df2.duplicated().value_counts()
# Out:
# False    1413
# Name: count, dtype: int64

# %%
# Looking for missing values
merged_df2.isna().sum()
# Out:
# id                     0
# release_date           0
# title                  0
# production_budget      0
# domestic_gross_x       0
# worldwide_gross        0
# studio                 0
# domestic_gross_y       1
# foreign_gross        198
# year                   0
# tconst                 0
# original_title         0
# start_year             0
# runtime_minutes       30
# genres                 7
# averagerating          0
# numvotes               0
# dtype: int64

# %%
# Dropping null values
merged_df2.dropna()
# Out:
#       id  release_date                                        title  \
# 0      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1      4   May 1, 2015                      Avengers: Age of Ultron
# 2      7  Apr 27, 2018                       Avengers: Infinity War
# 3      9  Nov 17, 2017                               Justice League
# 4     10   Nov 6, 2015                                      Spectre
# ...   ..           ...                                          ...
# 1402  17  Jul 27, 2001                                      Jackpot
# 1404  74  Oct 28, 2011                                   Like Crazy
# 1405  74  Oct 28, 2011                                   Like Crazy
# 1407  48  Jul 22, 2011                                Another Earth
# 1410  80  Jul 10, 2015                                  The Gallows
#
#      production_budget domestic_gross_x worldwide_gross   studio  \
# 0         $410,600,000     $241,063,875  $1,045,663,875       BV
# ...

# %%
# Dropping duplicated columns
columns_to_drop = ['original_title', 'year', 'start_year', 'foreign_gross', 'domestic_gross_y']
merged_df2 = merged_df2.drop(columns_to_drop, axis=1)

merged_df2
# Out:
#       id  release_date                                        title  \
# 0      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1      4   May 1, 2015                      Avengers: Age of Ultron
# 2      7  Apr 27, 2018                       Avengers: Infinity War
# 3      9  Nov 17, 2017                               Justice League
# 4     10   Nov 6, 2015                                      Spectre
# ...   ..           ...                                          ...
# 1408  68  Apr 27, 2012                            Sound of My Voice
# 1409  73  Jun 15, 2012                         Your Sister's Sister
# 1410  80  Jul 10, 2015                                  The Gallows
# 1411  86   Jul 7, 2017                                A Ghost Story
# 1412  18  Nov 12, 2010                               Tiny Furniture
#
#      production_budget domestic_gross_x worldwide_gross   studio     tconst  \
# ...

# %%
merged_df2.rename(columns={'production_budget': 'Budget', 'release_date': 'Date',
                           'domestic_gross_x': 'Domestic_sales', 'worldwide_gross': 'International_sales',
                           'runtime_minutes': 'Runtime', 'averagerating': 'Rating',
                           'id': 'ID', 'title': 'Title',
                           'studio': 'Studio', 'genres': 'Genres', 'numvotes': 'Votes', 'tconst': 'Tconst'}, inplace=True)
merged_df2
# Out:
#       ID          Date                                        Title  \
# 0      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1      4   May 1, 2015                      Avengers: Age of Ultron
# 2      7  Apr 27, 2018                       Avengers: Infinity War
# 3      9  Nov 17, 2017                               Justice League
# 4     10   Nov 6, 2015                                      Spectre
# ...   ..           ...                                          ...
# 1408  68  Apr 27, 2012                            Sound of My Voice
# 1409  73  Jun 15, 2012                         Your Sister's Sister
# 1410  80  Jul 10, 2015                                  The Gallows
# 1411  86   Jul 7, 2017                                A Ghost Story
# 1412  18  Nov 12, 2010                               Tiny Furniture
#
#             Budget Domestic_sales International_sales   Studio     Tconst  \
# 0     $410,600,000   $241,063,875      $1,045,663,875       BV  tt1298650
# ...

# %%
# Dropping null values
merged_df2.dropna()
# Out:
#       ID          Date                                        Title  \
# 0      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 1      4   May 1, 2015                      Avengers: Age of Ultron
# 2      7  Apr 27, 2018                       Avengers: Infinity War
# 3      9  Nov 17, 2017                               Justice League
# 4     10   Nov 6, 2015                                      Spectre
# ...   ..           ...                                          ...
# 1408  68  Apr 27, 2012                            Sound of My Voice
# 1409  73  Jun 15, 2012                         Your Sister's Sister
# 1410  80  Jul 10, 2015                                  The Gallows
# 1411  86   Jul 7, 2017                                A Ghost Story
# 1412  18  Nov 12, 2010                               Tiny Furniture
#
#             Budget Domestic_sales International_sales   Studio     Tconst  \
# 0     $410,600,000   $241,063,875      $1,045,663,875       BV  tt1298650
# ...

# %%
merged_df2.head(20)
# Out:
#     ID          Date                                             Title  \
# 0    2  May 20, 2011       Pirates of the Caribbean: On Stranger Tides
# 1    4   May 1, 2015                           Avengers: Age of Ultron
# 2    7  Apr 27, 2018                            Avengers: Infinity War
# 3    9  Nov 17, 2017                                    Justice League
# 4   10   Nov 6, 2015                                           Spectre
# 5   11  Jul 20, 2012                             The Dark Knight Rises
# 6   12  May 25, 2018                           Solo: A Star Wars Story
# 7   13   Jul 2, 2013                                   The Lone Ranger
# 8   14   Mar 9, 2012                                       John Carter
# 9   15  Nov 24, 2010                                           Tangled
# 10  17   May 6, 2016                        Captain America: Civil War
# 11  18  Mar 25, 2016                Batman v Superman: Dawn of Justice
# ...

# %%
# Data frame
data = {
    'ID': [2, 4, 7, 9, 10, 11, 12, 13, 14, 15, 17, 18, 19, 21, 22, 23, 25, 29, 31, 32],
    'Title': ['Pirates of the Caribbean: On Stranger Tides', 'Avengers: Age of Ultron', 'Avengers: Infinity War', 
              'Justice League', 'Spectre', 'The Dark Knight Rises', 'Solo: A Star Wars Story', 
              'The Lone Ranger', 'John Carter', 'Tangled', 'Captain America: Civil War', 
              'Batman v Superman: Dawn of Justice', 'The Hobbit: An Unexpected Journey', 
              'The Hobbit: The Desolation of Smaug', 'The Hobbit: The Battle of the Five Armies', 
              'The Fate of the Furious', 'Pirates of the Caribbean: Dead Men Tell No Tales', 
              'Man of Steel', 'The Amazing Spider-Man', 'Battleship'],
    'Budget': [410600000, 330600000, 300000000, 300000000, 300000000, 275000000, 275000000, 
               275000000, 275000000, 260000000, 250000000, 250000000, 250000000, 250000000, 
               250000000, 250000000, 230000000, 225000000, 220000000, 220000000],
    'Domestic_sales': [241063875, 459005868, 678815482, 229024295, 200074175, 448139099, 213767512, 
                       89302115, 73058679, 200821936, 408084349, 330360194, 303003568, 258366855, 
                       255119788, 225764765, 172558876, 291045518, 262030663, 65233400],
    'International_sales': [1045663875, 1403013963, 2048134200, 655945209, 879620923, 1084439099, 
                            393151347, 260002115, 282778100, 586477240, 1140069413, 867500281, 
                            1017003568, 960366855, 945577621, 1234846267, 788241137, 667999518, 
                            757890267, 313477717],
    'Genres': ['Action,Adventure,Fantasy', 'Action,Adventure,Sci-Fi', 'Action,Adventure,Sci-Fi', 
               'Action,Adventure,Fantasy', 'Action,Adventure,Thriller', 'Action,Thriller', 
               'Action,Adventure,Fantasy', 'Action,Adventure,Western', 'Action,Adventure,Sci-Fi', 
               'Adventure,Animation,Comedy', 'Action,Adventure,Sci-Fi', 'Action,Adventure,Fantasy', 
               'Adventure,Family,Fantasy', 'Adventure,Fantasy', 'Adventure,Fantasy', 
               'Action,Crime,Thriller', 'Action,Adventure,Fantasy', 'Action,Adventure,Sci-Fi', 
               'Action,Adventure,Sci-Fi', 'Action,Adventure,Sci-Fi']
}

df = pd.DataFrame(data)

# Convert columns to float
df['Budget'] = df['Budget'].astype(float)
df['Domestic_sales'] = df['Domestic_sales'].astype(float)
df['International_sales'] = df['International_sales'].astype(float)

# Calculate profit for each movie
df['Profit'] = (df['Domestic_sales'] + df['International_sales']) - df['Budget']
df['Profit'] = df['Profit'] / 10000000  # Convert to millions

# Create a list to store genre-wise profit
genre_profit_list = []

for index, row in df.iterrows():
    genres = row['Genres'].split(',')
    for genre in genres:
        genre_profit_list.append({'Genre': genre, 'Profit': row['Profit']})

# Create a DataFrame from the list
genre_profit = pd.DataFrame(genre_profit_list)

# Remove null values
genre_profit = genre_profit.dropna()

# Calculate total profit for each genre
genre_profit = genre_profit.groupby('Genre')['Profit'].sum().reset_index()

# Sort the DataFrame based on 'Profit' in ascending order
genre_profit = genre_profit.sort_values(by='Profit', ascending=False)

# Create bar plot using seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='Profit', y='Genre', data=genre_profit,palette="light:b" "_r", edgecolor='black')
plt.title('Profit by Genre (in Millions)', fontsize=16)
plt.xlabel('Profit (Millions)', fontsize=14,labelpad=15)
plt.ylabel('Genre', fontsize=14,labelpad=15)
plt.show()

# %%
# Data frame
data = {
    'ID': [2, 4, 7, 9, 10, 11, 12, 13, 14, 15, 17, 18, 19, 21, 22, 23, 25, 29, 31, 32],
    'Date': ['May 20, 2011', 'May 1, 2015', 'Apr 27, 2018', 'Nov 17, 2017', 'Nov 6, 2015', 
             'Jul 20, 2012', 'May 25, 2018', 'Jul 2, 2013', 'Mar 9, 2012', 'Nov 24, 2010', 
             'May 6, 2016', 'Mar 25, 2016', 'Dec 14, 2012', 'Dec 13, 2013', 'Dec 17, 2014', 
             'Apr 14, 2017', 'May 26, 2017', 'Jun 14, 2013', 'Jul 3, 2012', 'May 18, 2012'],
    'Title': ['Pirates of the Caribbean: On Stranger Tides', 'Avengers: Age of Ultron', 'Avengers: Infinity War', 
              'Justice League', 'Spectre', 'The Dark Knight Rises', 'Solo: A Star Wars Story', 
              'The Lone Ranger', 'John Carter', 'Tangled', 'Captain America: Civil War', 
              'Batman v Superman: Dawn of Justice', 'The Hobbit: An Unexpected Journey', 
              'The Hobbit: The Desolation of Smaug', 'The Hobbit: The Battle of the Five Armies', 
              'The Fate of the Furious', 'Pirates of the Caribbean: Dead Men Tell No Tales', 
              'Man of Steel', 'The Amazing Spider-Man', 'Battleship'],
    'Runtime': [136.0, 141.0, 149.0, 120.0, 148.0, 164.0, 135.0, 150.0, 132.0, 100.0, 
                147.0, 151.0, 169.0, 161.0, 144.0, 136.0, 129.0, 143.0, 136.0, 131.0],
    'Votes': [447624, 665594, 670926, 329135, 352504, 1387769, 226243, 208827, 241792, 
              366366, 583507, 576909, 719629, 565563, 438621, 179774, 228592, 647288, 
              525632, 225342]
}

df = pd.DataFrame(data)

# Filter rows based on runtime and remove null values
filtered_df = df[(df['Runtime'].between(60, 150)) & (df['Votes'].notnull())]

# Sort the dataframe based on 'Runtime' in ascending order
filtered_df = filtered_df.sort_values(by='Runtime')

# Create bar plot using seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='Runtime', y='Votes', data=filtered_df, palette="light:b", edgecolor='black')
plt.title('Votes vs Runtime', fontsize=16)
plt.xlabel('Runtime (minutes)', fontsize=14,labelpad=15)
plt.ylabel('Votes', fontsize=14,labelpad=20)
plt.show()

# %%
#Data frame

data = {
    'ID': [2, 4, 7, 9, 10, 11, 12, 13, 14, 15, 17, 18, 19, 21, 22, 23, 25, 29, 31, 32],
    'Title': ['Pirates of the Caribbean: On Stranger Tides', 'Avengers: Age of Ultron', 'Avengers: Infinity War', 
              'Justice League', 'Spectre', 'The Dark Knight Rises', 'Solo: A Star Wars Story', 
              'The Lone Ranger', 'John Carter', 'Tangled', 'Captain America: Civil War', 
              'Batman v Superman: Dawn of Justice', 'The Hobbit: An Unexpected Journey', 
              'The Hobbit: The Desolation of Smaug', 'The Hobbit: The Battle of the Five Armies', 
              'The Fate of the Furious', 'Pirates of the Caribbean: Dead Men Tell No Tales', 
              'Man of Steel', 'The Amazing Spider-Man', 'Battleship'],
    'Budget': ['$410,600,000', '$330,600,000', '$300,000,000', '$300,000,000', '$300,000,000', 
               '$275,000,000', '$275,000,000', '$275,000,000', '$275,000,000', '$260,000,000', 
               '$250,000,000', '$250,000,000', '$250,000,000', '$250,000,000', '$250,000,000', 
               '$250,000,000', '$230,000,000', '$225,000,000', '$220,000,000', '$220,000,000'],
    'Domestic_sales': ['$241,063,875', '$459,005,868', '$678,815,482', '$229,024,295', '$200,074,175', 
                       '$448,139,099', '$213,767,512', '$89,302,115', '$73,058,679', '$200,821,936', 
                       '$408,084,349', '$330,360,194', '$303,003,568', '$258,366,855', '$255,119,788', 
                       '$225,764,765', '$172,558,876', '$291,045,518', '$262,030,663', '$65,233,400'],
    'International_sales': ['$1,045,663,875', '$1,403,013,963', '$2,048,134,200', '$655,945,209', '$879,620,923', 
                            '$1,084,439,099', '$393,151,347', '$260,002,115', '$282,778,100', '$586,477,240', 
                            '$1,140,069,413', '$867,500,281', '$1,017,003,568', '$960,366,855', '$945,577,621', 
                            '$1,234,846,267', '$788,241,137', '$667,999,518', '$757,890,267', '$313,477,717'],
    'Studio': ['BV', 'BV', 'BV', 'WB', 'Sony', 'WB', 'BV', 'BV', 'BV', 'BV', 'BV', 'WB', 'WB (NL)', 'WB (NL)', 'WB (NL)', 'Uni.', 'BV', 'WB', 'Sony', 'Uni.'],
    'Runtime': [136.0, 141.0, 149.0, 120.0, 148.0, 164.0, 135.0, 150.0, 132.0, 100.0, 147.0, 
                151.0, 169.0, 161.0, 144.0, 136.0, 129.0, 143.0, 136.0, 131.0],
    'Genres': ['Action,Adventure,Fantasy', 'Action,Adventure,Sci-Fi', 'Action,Adventure,Sci-Fi', 
               'Action,Adventure,Fantasy', 'Action,Adventure,Thriller', 'Action,Thriller', 
               'Action,Adventure,Fantasy', 'Action,Adventure,Western', 'Action,Adventure,Sci-Fi', 
               'Adventure,Animation,Comedy', 'Action,Adventure,Sci-Fi', 'Action,Adventure,Fantasy', 
               'Adventure,Family,Fantasy', 'Adventure,Fantasy', 'Adventure,Fantasy', 
               'Action,Crime,Thriller', 'Action,Adventure,Fantasy', 'Action,Adventure,Sci-Fi', 
               'Action,Adventure,Sci-Fi', 'Action,Adventure,Sci-Fi'],
    'Rating': [6.6, 7.3, 8.5, 6.5, 6.8, 8.4, 7.0, 6.4, 6.6, 7.8, 7.8, 6.5, 7.9, 7.8, 7.4, 6.7, 6.6, 7.1, 7.0, 5.8],
    'Votes': [447624, 665594, 670926, 329135, 352504, 1387769, 226243, 208827, 241792, 366366, 
              583507, 576909, 719629, 565563, 438621, 179774, 228592, 647288, 525632, 225342]
}

df = pd.DataFrame(data)

# Convert columns to float
df['Budget'] = df['Budget'].str.replace('$', '').str.replace(',', '').astype(float)
df['Domestic_sales'] = df['Domestic_sales'].str.replace('$', '').str.replace(',', '').astype(float)
df['International_sales'] = df['International_sales'].str.replace('$', '').str.replace(',', '').astype(float)

# Calculate profit
df['Profit'] = (df['Domestic_sales'] + df['International_sales']) - df['Budget']

# Remove null values
df = df.dropna()

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Profit', y='Studio', data=df, estimator=sum, palette="light:b""_r", edgecolor='black', errcolor='none')
plt.title('Total Profit by Studio',fontsize=14)
plt.xlabel('Total Profit (in billions)',labelpad=15)
plt.ylabel('Studio',fontsize=14,labelpad=15)
plt.show()
