# %%
Student_name = ('Roland Bennette Valencia')
Student_pace = ('Part time')
Scheduled_project = ('March 31 2024')
Instructor_name = ('Rajive Islam')

# %%
# Part 1 is analyzing,merging and cleaning of data.

# %%
# Importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
# Uploading data frame 1
df1 = pd.read_csv('imdb.title.ratings.csv.gz')
df1
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
# To look for null values
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
# To show basic statistics
df1.describe()
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
# Uploading data frame 2
df2 = pd.read_csv('imdb.title.basics.csv.gz')
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
# Uploading data frame 3
df3 = pd.read_csv('bom.movie_gross.csv.gz')
df3
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
# Merging data frames 1 and 2 using 'inner join'.

merged_df = pd.merge(df2,df1,on='tconst',how='inner')
merged_df
# Out:
#           tconst                    primary_title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
# Renaming column name for merging merged_df to df3
merged_df.rename(columns={'primary_title': 'title'}, inplace=True)
merged_df
# Out:
#           tconst                            title              original_title  \
# 0      tt0063540                        Sunghursh                   Sunghursh
# 1      tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2      tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3      tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4      tt0100275         The Wandering Soap Opera       La Telenovela Errante
# ...          ...                              ...                         ...
# 73851  tt9913084                 Diabolik sono io            Diabolik sono io
# 73852  tt9914286                Sokagin Çocuklari           Sokagin Çocuklari
# 73853  tt9914642                        Albatross                   Albatross
# 73854  tt9914942       La vida sense la Sara Amat  La vida sense la Sara Amat
# 73855  tt9916160                       Drømmeland                  Drømmeland
#
# ...

# %%
# Merging data frame 3 with data frames 1 and 2 using 'title' as primary key and using 'outer join'.

merged_df1 = pd.merge(df3,merged_df,on='title',how='outer')
merged_df1
# Out:
#                                              title studio  domestic_gross  \
# 0                                      Toy Story 3     BV     415000000.0
# 1                       Alice in Wonderland (2010)     BV     334200000.0
# 2      Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                        Inception     WB     292600000.0
# 4                              Shrek Forever After   P/DW     238700000.0
# ...                                            ...    ...             ...
# 74641                    Padmavyuhathile Abhimanyu    NaN             NaN
# 74642                                 Swarm Season    NaN             NaN
# 74643                             Diabolik sono io    NaN             NaN
# 74644                            Sokagin Çocuklari    NaN             NaN
# 74645                   La vida sense la Sara Amat    NaN             NaN
#
#       foreign_gross    year     tconst              original_title  \
# ...

# %%
# Dropping original_title in the columns list
merged_df1 = merged_df1.drop('original_title', axis=1) 
merged_df1
# Out:
#                                              title studio  domestic_gross  \
# 0                                      Toy Story 3     BV     415000000.0
# 1                       Alice in Wonderland (2010)     BV     334200000.0
# 2      Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                        Inception     WB     292600000.0
# 4                              Shrek Forever After   P/DW     238700000.0
# ...                                            ...    ...             ...
# 74641                    Padmavyuhathile Abhimanyu    NaN             NaN
# 74642                                 Swarm Season    NaN             NaN
# 74643                             Diabolik sono io    NaN             NaN
# 74644                            Sokagin Çocuklari    NaN             NaN
# 74645                   La vida sense la Sara Amat    NaN             NaN
#
#       foreign_gross    year     tconst  start_year  runtime_minutes  \
# ...

# %%
# To look for duplicate values
merged_df1.duplicated().value_counts()
# Out:
# False    74646
# Name: count, dtype: int64

# %%
# Looking for missing values
merged_df1.isna().sum()
# Out:
# title                  0
# studio             70836
# domestic_gross     70864
# foreign_gross      72335
# year               70831
# tconst               788
# start_year           788
# runtime_minutes     8408
# genres              1592
# averagerating        788
# numvotes             788
# dtype: int64

# %%
merged_df1.describe()
# Out:
#        domestic_gross         year    start_year  runtime_minutes  \
# count    3.782000e+03  3815.000000  73858.000000     66238.000000
# mean     2.872771e+07  2013.987418   2014.276138        94.654428
# std      6.619343e+07     2.488221      2.614804       208.570981
# min      1.000000e+02  2010.000000   2010.000000         3.000000
# 25%      1.210000e+05  2012.000000   2012.000000        81.000000
# 50%      1.450000e+06  2014.000000   2014.000000        91.000000
# 75%      2.900000e+07  2016.000000   2016.000000       104.000000
# max      9.367000e+08  2018.000000   2019.000000     51420.000000
#
#        averagerating      numvotes
# count   73858.000000  7.385800e+04
# mean        6.332726  3.523584e+03
# std         1.474959  3.029362e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
# To look for null values
merged_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74646 entries, 0 to 74645
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            74646 non-null  object
#  1   studio           3810 non-null   object
#  2   domestic_gross   3782 non-null   float64
#  3   foreign_gross    2311 non-null   object
#  4   year             3815 non-null   float64
#  5   tconst           73858 non-null  object
#  6   start_year       73858 non-null  float64
#  7   runtime_minutes  66238 non-null  float64
#  8   genres           73054 non-null  object
#  9   averagerating    73858 non-null  float64
#  10  numvotes         73858 non-null  float64
# dtypes: float64(6), object(5)
# memory usage: 6.3+ MB

# %%
# Capitalizing the name of columns
merged_df1.rename(columns={'title':'Title','studio':'Studio','domestic_gross':'Domestic_gross','foreign_gross':'Foreign_gross','year':'Year','tconst':'Tconst','start_year':'Start_year','runtime_minutes':'Runtime_minutes','genres':'Genres','averagerating':'Average_rating','numvotes':'Number_of_votes'}, inplace=True)

# %%
#drops rows with missing values
merged_df1.dropna()
# Out:
#                                         Title      Studio  Domestic_gross  \
# 0                                 Toy Story 3          BV     415000000.0
# 3                                   Inception          WB     292600000.0
# 4                         Shrek Forever After        P/DW     238700000.0
# 5                  The Twilight Saga: Eclipse        Sum.     300500000.0
# 6                                  Iron Man 2        Par.     312400000.0
# ...                                       ...         ...             ...
# 3682               Bilal: A New Breed of Hero          VE        491000.0
# 3686                          I Still See You         LGF          1400.0
# 3698                    The Catcher Was a Spy         IFC        725000.0
# 3727                               Time Freak  Grindstone         10000.0
# 3777  Antonio Lopez 1970: Sex Fashion & Disco          FM         43200.0
#
#      Foreign_gross    Year     Tconst  Start_year  Runtime_minutes  \
# ...

# %%
merged_df1['Start_year'].value_counts().head(10).plot(kind='bar', title='Yea')
# Out:
# <Axes: title={'center': 'Yea'}, xlabel='Start_year'>

# %%
#plot = merged_df1.plot(title='Merged_df1', kind='bar');

# %%
merged_df1.plot();

# %%
# Dropping Year in the columns list
merged_df1 = merged_df1.drop('Year', axis=1) 
merged_df1
# Out:
#                                              Title Studio  Domestic_gross  \
# 0                                      Toy Story 3     BV     415000000.0
# 1                       Alice in Wonderland (2010)     BV     334200000.0
# 2      Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                        Inception     WB     292600000.0
# 4                              Shrek Forever After   P/DW     238700000.0
# ...                                            ...    ...             ...
# 74641                    Padmavyuhathile Abhimanyu    NaN             NaN
# 74642                                 Swarm Season    NaN             NaN
# 74643                             Diabolik sono io    NaN             NaN
# 74644                            Sokagin Çocuklari    NaN             NaN
# 74645                   La vida sense la Sara Amat    NaN             NaN
#
#       Foreign_gross     Tconst  Start_year  Runtime_minutes  \
# ...

# %%
# Capitalizing the name of columns
merged_df1.rename(columns={'title':'Title','studio':'Studio','domestic_gross':'Domestic_gross','foreign_gross':'Foreign_gross','tconst':'Tconst','start_year':'Start_year','runtime_minutes':'Runtime_minutes','genres':'Genres','averagerating':'Average_rating','numvotes':'Number_of_votes'}, inplace=True)

# %%
merged_df1
# Out:
#                                              Title Studio  Domestic_gross  \
# 0                                      Toy Story 3     BV     415000000.0
# 1                       Alice in Wonderland (2010)     BV     334200000.0
# 2      Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                        Inception     WB     292600000.0
# 4                              Shrek Forever After   P/DW     238700000.0
# ...                                            ...    ...             ...
# 74641                    Padmavyuhathile Abhimanyu    NaN             NaN
# 74642                                 Swarm Season    NaN             NaN
# 74643                             Diabolik sono io    NaN             NaN
# 74644                            Sokagin Çocuklari    NaN             NaN
# 74645                   La vida sense la Sara Amat    NaN             NaN
#
#       Foreign_gross     Tconst  Start_year  Runtime_minutes  \
# ...

# %%
#drops rows with missing values
merged_df1.dropna()
# Out:
#                                         Title      Studio  Domestic_gross  \
# 0                                 Toy Story 3          BV     415000000.0
# 3                                   Inception          WB     292600000.0
# 4                         Shrek Forever After        P/DW     238700000.0
# 5                  The Twilight Saga: Eclipse        Sum.     300500000.0
# 6                                  Iron Man 2        Par.     312400000.0
# ...                                       ...         ...             ...
# 3682               Bilal: A New Breed of Hero          VE        491000.0
# 3686                          I Still See You         LGF          1400.0
# 3698                    The Catcher Was a Spy         IFC        725000.0
# 3727                               Time Freak  Grindstone         10000.0
# 3777  Antonio Lopez 1970: Sex Fashion & Disco          FM         43200.0
#
#      Foreign_gross     Tconst  Start_year  Runtime_minutes  \
# ...

# %%
merged_df1.plot()
# Out:
# <Axes: >
